# %% [markdown]
# ### Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\suryansh tomar\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\suryansh tomar\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %% [markdown]
# ### Prepare/collect data

# %%
import os
os.sys.path

path = os.listdir('brain_tumor/Training/')
classes = {'no_disease':0, 'pituitary_tumor':1, 'moderate_alzheimer': 2}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = 'brain_tumor/Training/'+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
X = np.array(X)
Y = np.array(Y)

X_updated = X.reshape(len(X), -1)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2])

# %%
pd.Series(Y).value_counts()
# Out:
# 0    1397
# 1     827
# 2     495
# dtype: int64

# %%
X.shape, X_updated.shape
# Out:
# ((2288, 200, 200), (2288, 40000))

# %% [markdown]
# ### Visualize data

# %%
plt.imshow(X[0], cmap='gray')

# %% [markdown]
# ### Prepare data

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (2719, 40000)

# %% [markdown]
# ### Split Data

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10,
                                               test_size=.20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((1830, 40000), (458, 40000))

# %% [markdown]
# ### Feature Scaling

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### Feature Selection: PCA

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
# pca_train = pca.fit_transform(xtrain)
# pca_test = pca.transform(xtest)
pca_train = xtrain
pca_test = xtest
# Out:
# (2175, 40000) (544, 40000)

# %%
# print(pca_train.shape, pca_test.shape)
# print(pca.n_components_)
# print(pca.n_features_)

# %% [markdown]
# ### Train Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

lg = LogisticRegression(C=0.1)
lg.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=0.1)

# %%
sv = SVC()
sv.fit(xtrain, ytrain)
# Out:
# SVC()

# %% [markdown]
# ### Evaluation

# %%
print("Training Score:", lg.score(xtrain, ytrain))
print("Testing Score:", lg.score(xtest, ytest))
# Out:
# Training Score: 1.0
# Testing Score: 0.9595588235294118

# %%
print("Training Score:", sv.score(xtrain, ytrain))
print("Testing Score:", sv.score(xtest, ytest))
# Out:
# Training Score: 0.9903448275862069
# Testing Score: 0.9650735294117647

# %% [markdown]
# ### Prediction

# %%
pred = lg.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pred = lg.predict(xtest)
#
# NameError: name 'lg' is not defined

# %%
misclassified=np.where(ytest!=pred)
misclassified
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 misclassified=np.where(ytest!=pred)
#       2 misclassified
#
# NameError: name 'np' is not defined

# %%
print("Total Misclassified Samples: ",len(misclassified[0]))
#print(pred[36],ytest[36])
# Out:
# Total Misclassified Samples:  22

# %% [markdown]
# ### TEST MODEL

# %%
dec = {0:'No Disease', 1:'Positive Tumor', 2:'Positive Alzheimer'}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('brain_tumor/Testing/')
c=1
for i in os.listdir('brain_tumor/Testing/no_disease/')[9:18]:
    plt.subplot(3,3,c)
    
    img = cv2.imread('brain_tumor/Testing/no_disease/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = lg.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
plt.figure(figsize=(12,8))
p = os.listdir('brain_tumor/Testing/')
c=1
for i in os.listdir('brain_tumor/Testing/pituitary_tumor/')[:16]:
    plt.subplot(4,4,c)
    
    img = cv2.imread('brain_tumor/Testing/pituitary_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = lg.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 plt.figure(figsize=(12,8))
#       2 p = os.listdir('brain_tumor/Testing/')
#       3 c=1
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(12,8))
p = os.listdir('brain_tumor/Testing/')
c=1
for i in os.listdir('brain_tumor/Testing/moderate_test/')[:16]:
    plt.subplot(4,4,c)
    
    img = cv2.imread('brain_tumor/Testing/moderate_test/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = lg.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
